# %%
import numpy as np
import gym
import gym_organism

env = gym.make("Organism-v0")

env.reset() # reset environment to a new, random state

q_table = np.zeros([env.observation_space.n, env.action_space.n])


"""Training the agent"""
print("How many generations ?")
gen = int(input())

import random
from time import sleep
from IPython.display import clear_output

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1
gen_done = False
for j in range(gen):
    
    print("Gen : ", j+1)
    time_taken = 0
    total_penalty = 0
    # For plotting metrics
    all_epochs = []
    all_penalties = []
    frames = []
    times_eaten = 0
    for i in range(1, 101):
        epochs, penalties, reward, = 0, 0, 0
        done = False
        state = env.reset()
        while epochs<20 and not done:
            if random.uniform(0, 1) < epsilon:
                action = env.action_space.sample() # Explore action space
            else:
                action = np.argmax(q_table[state]) # Exploit learned values

            next_state, reward, done, info = env.step(action)

            old_value = q_table[state, action]
            next_max = np.max(q_table[next_state])

            new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
            q_table[state, action] = new_value

            if reward == -10:
                penalties += 1

            frames.append({
            'frame': env.render(mode='ansi'),
            'state': state,
            'action': action,
            'reward': reward
            }
        )

#             state = next_state

#             epochs += 1

#         if i % 100 == 0:
#             clear_output(wait=True)
#             print(f"Episode: {i}")
#         time_taken += epochs
#     print(f"Total time in this generation is : {time_taken}")
#     print("Training finished.\n")
            state = next_state

            epochs += 1
#         print(done)
        if done:
            times_eaten+=1
            gen_done = True
        if i % 100 == 0:
            print(f"Episode: {i}")
        time_taken += epochs
        total_penalty += penalties

#     final_frames.append(frames)
    print(f"Total time in this generation is : {time_taken}, average time taken per episode of generation is : {time_taken/i}")
    print(f"Total penalty : {total_penalty} and average penalty : {total_penalty/100}")
    print(f"The number of times the organism ate : {times_eaten}")
    print("Training finished.\n")
# Out:
# How many generations ?
# 15
# Gen :  1
# Episode: 100
# Total time in this generation is : 1974, average time taken per episode of generation is : 19.74
# Total penalty : 207 and average penalty : 2.07
# The number of times the organism ate : 2
# Training finished.
#
# Gen :  2
# Episode: 100
# Total time in this generation is : 1894, average time taken per episode of generation is : 18.94
# Total penalty : 183 and average penalty : 1.83
# The number of times the organism ate : 11
# Training finished.
#
# Gen :  3
# Episode: 100
# Total time in this generation is : 1854, average time taken per episode of generation is : 18.54
# Total penalty : 78 and average penalty : 0.78
# The number of times the organism ate : 14
# Training finished.
#
# Gen :  4
# Episode: 100
# Total time in this generation is : 1844, average time taken per episode of generation is : 18.44
# Total penalty : 36 and average penalty : 0.36
# The number of times the organism ate : 16
# Training finished.
#
# Gen :  5
# Episode: 100
# Total time in this generation is : 1789, average time taken per episode of generation is : 17.89
# Total penalty : 36 and average penalty : 0.36
# The number of times the organism ate : 17
# Training finished.
#
# Gen :  6
# Episode: 100
# Total time in this generation is : 1792, average time taken per episode of generation is : 17.92
# Total penalty : 41 and average penalty : 0.41
# The number of times the organism ate : 13
# Training finished.
#
# Gen :  7
# Episode: 100
# Total time in this generation is : 1644, average time taken per episode of generation is : 16.44
# Total penalty : 36 and average penalty : 0.36
# The number of times the organism ate : 26
# Training finished.
#
# Gen :  8
# Episode: 100
# Total time in this generation is : 1871, average time taken per episode of generation is : 18.71
# Total penalty : 38 and average penalty : 0.38
# The number of times the organism ate : 12
# Training finished.
#
# Gen :  9
# Episode: 100
# Total time in this generation is : 1756, average time taken per episode of generation is : 17.56
# Total penalty : 43 and average penalty : 0.43
# The number of times the organism ate : 23
# Training finished.
#
# Gen :  10
# Episode: 100
# Total time in this generation is : 1686, average time taken per episode of generation is : 16.86
# Total penalty : 54 and average penalty : 0.54
# The number of times the organism ate : 29
# Training finished.
#
# Gen :  11
# Episode: 100
# Total time in this generation is : 1662, average time taken per episode of generation is : 16.62
# Total penalty : 66 and average penalty : 0.66
# The number of times the organism ate : 28
# Training finished.
#
# Gen :  12
# Episode: 100
# Total time in this generation is : 1701, average time taken per episode of generation is : 17.01
# Total penalty : 80 and average penalty : 0.8
# The number of times the organism ate : 26
# Training finished.
#
# Gen :  13
# Episode: 100
# Total time in this generation is : 1580, average time taken per episode of generation is : 15.8
# Total penalty : 45 and average penalty : 0.45
# The number of times the organism ate : 34
# Training finished.
#
# Gen :  14
# Episode: 100
# Total time in this generation is : 1613, average time taken per episode of generation is : 16.13
# Total penalty : 34 and average penalty : 0.34
# The number of times the organism ate : 32
# Training finished.
#
# Gen :  15
# Episode: 100
# Total time in this generation is : 1582, average time taken per episode of generation is : 15.82
# Total penalty : 36 and average penalty : 0.36
# The number of times the organism ate : 37
# Training finished.

# %%
def print_frames(frames):
    for i, frame in enumerate(frames):
        clear_output(wait=True)
        print(frame['frame'])
        print(f"Timestep: {i + 1}")
        print(f"State: {frame['state']}")
        print(f"Action: {frame['action']}")
        print(f"Reward: {frame['reward']}")
        sleep(.1)

print_frames(frames)
# Out:
# +-------------------+
# |x: | : : : : : : : |
# | : | : : : : | : | |
# | : : : : : : : : : |
# | | : | : : | : :x: |
# |x| : | : : : : : | |
# | : : : : : | : : : |
# | : : : | : | : : : |
# | : | : : | : : : | |
# | : : : : : : : : : |
# | : | : : : : : | :x|
# +-------------------+
#   (North)
#
# Timestep: 1314
# State: 19
# Action: 1
# Reward: -1
