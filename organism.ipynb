# %%
import numpy as np
import gym
import gym_organism

env = gym.make("Organism-v0")

env.reset() # reset environment to a new, random state

q_table = np.zeros([env.observation_space.n, env.action_space.n])


"""Training the agent"""
print("How many generations ?")
gen = int(input())

import random
from time import sleep
from IPython.display import clear_output

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1
gen_done = False
for j in range(gen):
    
    print("Gen : ", j+1)
    time_taken = 0
    total_penalty = 0
    # For plotting metrics
    all_epochs = []
    all_penalties = []
    frames = []
    times_eaten = 0
    if j == 0:
        #If it is the first generation
        for i in range(1, 101):
            epochs, penalties, reward, = 0, 0, 0
            done = False
            state = env.reset()
            while epochs<100 and not done:
                if random.uniform(0, 1) < epsilon:
                    action = env.action_space.sample() # Explore action space
                else:
                    action = np.argmax(q_table[state]) # Exploit learned values

                next_state, reward, done, info = env.step(action)

                old_value = q_table[state, action]
                next_max = np.max(q_table[next_state])

                new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                q_table[state, action] = new_value

                if reward == -10:
                    penalties += 1

                frames.append({
                'frame': env.render(mode='ansi'),
                'state': state,
                'action': action,
                'reward': reward
                }
            )

    #             state = next_state

    #             epochs += 1

    #         if i % 100 == 0:
    #             clear_output(wait=True)
    #             print(f"Episode: {i}")
    #         time_taken += epochs
    #     print(f"Total time in this generation is : {time_taken}")
    #     print("Training finished.\n")
                state = next_state

                epochs += 1
    #         print(done)
            if done:
                times_eaten+=1
                gen_done = True
            if i % 100 == 0:
                print(f"Episode: {i}")
            time_taken += epochs
            total_penalty += penalties
    else:
        if gen_done:
            gen_done = False
            for i in range(1, 101):
                epochs, penalties, reward, = 0, 0, 0
                done = False
                state = env.reset()
                while epochs<50 and not done:
                    if random.uniform(0, 1) < epsilon:
                        action = env.action_space.sample() # Explore action space
                    else:
                        action = np.argmax(q_table[state]) # Exploit learned values

                    next_state, reward, done, info = env.step(action)

                    old_value = q_table[state, action]
                    next_max = np.max(q_table[next_state])

                    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                    q_table[state, action] = new_value

                    if reward == -10:
                        penalties += 1

                    frames.append({
                    'frame': env.render(mode='ansi'),
                    'state': state,
                    'action': action,
                    'reward': reward
                    }
                )

        #             state = next_state

        #             epochs += 1

        #         if i % 100 == 0:
        #             clear_output(wait=True)
        #             print(f"Episode: {i}")
        #         time_taken += epochs
        #     print(f"Total time in this generation is : {time_taken}")
        #     print("Training finished.\n")
                    state = next_state

                    epochs += 1
        #         print(done)
                if done:
                    times_eaten+=1
                    gen_done = True
                if i % 100 == 0:
                    print(f"Episode: {i}")
                time_taken += epochs
                total_penalty += penalties
#     final_frames.append(frames)
    print(f"Total time in this generation is : {time_taken}, average time taken per episode of generation is : {time_taken/i}")
    print(f"Total penalty : {total_penalty} and average penalty : {total_penalty/100}")
    print(f"The number of times the organism ate : {times_eaten}")
    print("Training finished.\n")
# Out:
# How many generations ?
# 20
# Gen :  1
# Episode: 100
# Total time in this generation is : 9838, average time taken per episode of generation is : 98.38
# Total penalty : 885 and average penalty : 8.85
# The number of times the organism ate : 3
# Training finished.
#
# Gen :  2
# Episode: 100
# Total time in this generation is : 4953, average time taken per episode of generation is : 49.53
# Total penalty : 495 and average penalty : 4.95
# The number of times the organism ate : 1
# Training finished.
#
# Gen :  3
# Episode: 100
# Total time in this generation is : 4790, average time taken per episode of generation is : 47.9
# Total penalty : 590 and average penalty : 5.9
# The number of times the organism ate : 6
# Training finished.
#
# Gen :  4
# Episode: 100
# Total time in this generation is : 4878, average time taken per episode of generation is : 48.78
# Total penalty : 553 and average penalty : 5.53
# The number of times the organism ate : 5
# Training finished.
#
# Gen :  5
# Episode: 100
# Total time in this generation is : 4837, average time taken per episode of generation is : 48.37
# Total penalty : 534 and average penalty : 5.34
# The number of times the organism ate : 5
# Training finished.
#
# Gen :  6
# Episode: 100
# Total time in this generation is : 4795, average time taken per episode of generation is : 47.95
# Total penalty : 404 and average penalty : 4.04
# The number of times the organism ate : 6
# Training finished.
#
# Gen :  7
# Episode: 100
# Total time in this generation is : 4716, average time taken per episode of generation is : 47.16
# Total penalty : 271 and average penalty : 2.71
# The number of times the organism ate : 9
# Training finished.
#
# Gen :  8
# Episode: 100
# Total time in this generation is : 4819, average time taken per episode of generation is : 48.19
# Total penalty : 241 and average penalty : 2.41
# The number of times the organism ate : 8
# Training finished.
#
# Gen :  9
# Episode: 100
# Total time in this generation is : 4831, average time taken per episode of generation is : 48.31
# Total penalty : 135 and average penalty : 1.35
# The number of times the organism ate : 7
# Training finished.
#
# Gen :  10
# Episode: 100
# Total time in this generation is : 4741, average time taken per episode of generation is : 47.41
# Total penalty : 120 and average penalty : 1.2
# The number of times the organism ate : 8
# Training finished.
#
# Gen :  11
# Episode: 100
# Total time in this generation is : 4691, average time taken per episode of generation is : 46.91
# Total penalty : 101 and average penalty : 1.01
# The number of times the organism ate : 8
# Training finished.
#
# Gen :  12
# Episode: 100
# Total time in this generation is : 4668, average time taken per episode of generation is : 46.68
# Total penalty : 119 and average penalty : 1.19
# The number of times the organism ate : 10
# Training finished.
#
# Gen :  13
# Episode: 100
# Total time in this generation is : 4498, average time taken per episode of generation is : 44.98
# Total penalty : 86 and average penalty : 0.86
# The number of times the organism ate : 16
# Training finished.
#
# Gen :  14
# Episode: 100
# Total time in this generation is : 4750, average time taken per episode of generation is : 47.5
# Total penalty : 96 and average penalty : 0.96
# The number of times the organism ate : 10
# Training finished.
#
# Gen :  15
# Episode: 100
# Total time in this generation is : 4598, average time taken per episode of generation is : 45.98
# Total penalty : 96 and average penalty : 0.96
# The number of times the organism ate : 14
# Training finished.
#
# Gen :  16
# Episode: 100
# Total time in this generation is : 4641, average time taken per episode of generation is : 46.41
# Total penalty : 120 and average penalty : 1.2
# The number of times the organism ate : 9
# Training finished.
#
# Gen :  17
# Episode: 100
# Total time in this generation is : 4658, average time taken per episode of generation is : 46.58
# Total penalty : 92 and average penalty : 0.92
# The number of times the organism ate : 15
# Training finished.
#
# Gen :  18
# Episode: 100
# Total time in this generation is : 4704, average time taken per episode of generation is : 47.04
# Total penalty : 83 and average penalty : 0.83
# The number of times the organism ate : 11
# Training finished.
#
# Gen :  19
# Episode: 100
# Total time in this generation is : 4520, average time taken per episode of generation is : 45.2
# Total penalty : 108 and average penalty : 1.08
# The number of times the organism ate : 12
# Training finished.
#
# Gen :  20
# Episode: 100
# Total time in this generation is : 4769, average time taken per episode of generation is : 47.69
# Total penalty : 102 and average penalty : 1.02
# The number of times the organism ate : 8
# Training finished.
