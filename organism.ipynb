# %%
import numpy as np
import gym
import gym_organism

env = gym.make("Organism-v0")

env.reset() # reset environment to a new, random state

q_table = np.zeros([env.observation_space.n, env.action_space.n])


"""Training the agent"""
print("How many generations ?")
gen = int(input())

import random
from time import sleep
from IPython.display import clear_output

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1
gen_done = False
for j in range(gen):
    
    print("Gen : ", j+1)
    time_taken = 0
    total_penalty = 0
    # For plotting metrics
    all_epochs = []
    all_penalties = []
    frames = []
    times_eaten = 0
    if j == 0:
        #If it is the first generation
        for i in range(1, 101):
            epochs, penalties, reward, = 0, 0, 0
            done = False
            state = env.reset()
            while epochs<20 and not done:
                if random.uniform(0, 1) < epsilon:
                    action = env.action_space.sample() # Explore action space
                else:
                    action = np.argmax(q_table[state]) # Exploit learned values

                next_state, reward, done, info = env.step(action)

                old_value = q_table[state, action]
                next_max = np.max(q_table[next_state])

                new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                q_table[state, action] = new_value

                if reward == -10:
                    penalties += 1

                frames.append({
                'frame': env.render(mode='ansi'),
                'state': state,
                'action': action,
                'reward': reward
                }
            )

    #             state = next_state

    #             epochs += 1

    #         if i % 100 == 0:
    #             clear_output(wait=True)
    #             print(f"Episode: {i}")
    #         time_taken += epochs
    #     print(f"Total time in this generation is : {time_taken}")
    #     print("Training finished.\n")
                state = next_state

                epochs += 1
    #         print(done)
            if done:
                times_eaten+=1
                gen_done = True
            if i % 100 == 0:
                print(f"Episode: {i}")
            time_taken += epochs
            total_penalty += penalties
    else:
        if gen_done:
            gen_done = False
            for i in range(1, 101):
                epochs, penalties, reward, = 0, 0, 0
                done = False
                state = env.reset()
                while epochs<20 and not done:
                    if random.uniform(0, 1) < epsilon:
                        action = env.action_space.sample() # Explore action space
                    else:
                        action = np.argmax(q_table[state]) # Exploit learned values

                    next_state, reward, done, info = env.step(action)

                    old_value = q_table[state, action]
                    next_max = np.max(q_table[next_state])

                    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                    q_table[state, action] = new_value

                    if reward == -10:
                        penalties += 1

                    frames.append({
                    'frame': env.render(mode='ansi'),
                    'state': state,
                    'action': action,
                    'reward': reward
                    }
                )

        #             state = next_state

        #             epochs += 1

        #         if i % 100 == 0:
        #             clear_output(wait=True)
        #             print(f"Episode: {i}")
        #         time_taken += epochs
        #     print(f"Total time in this generation is : {time_taken}")
        #     print("Training finished.\n")
                    state = next_state

                    epochs += 1
        #         print(done)
                if done:
                    times_eaten+=1
                    gen_done = True
                if i % 100 == 0:
                    print(f"Episode: {i}")
                time_taken += epochs
                total_penalty += penalties
#     final_frames.append(frames)
    print(f"Total time in this generation is : {time_taken}, average time taken per episode of generation is : {time_taken/i}")
    print(f"Total penalty : {total_penalty} and average penalty : {total_penalty/100}")
    print(f"The number of times the organism ate : {times_eaten}")
    print("Training finished.\n")
# Out:
# How many generations ?
# 25
# Gen :  1
# Episode: 100
# Total time in this generation is : 1989, average time taken per episode of generation is : 19.89
# Total penalty : 204 and average penalty : 2.04
# The number of times the organism ate : 1
# Training finished.
#
# Gen :  2
# Episode: 100
# Total time in this generation is : 1932, average time taken per episode of generation is : 19.32
# Total penalty : 194 and average penalty : 1.94
# The number of times the organism ate : 7
# Training finished.
#
# Gen :  3
# Episode: 100
# Total time in this generation is : 1921, average time taken per episode of generation is : 19.21
# Total penalty : 60 and average penalty : 0.6
# The number of times the organism ate : 7
# Training finished.
#
# Gen :  4
# Episode: 100
# Total time in this generation is : 1877, average time taken per episode of generation is : 18.77
# Total penalty : 38 and average penalty : 0.38
# The number of times the organism ate : 13
# Training finished.
#
# Gen :  5
# Episode: 100
# Total time in this generation is : 1845, average time taken per episode of generation is : 18.45
# Total penalty : 34 and average penalty : 0.34
# The number of times the organism ate : 15
# Training finished.
#
# Gen :  6
# Episode: 100
# Total time in this generation is : 1818, average time taken per episode of generation is : 18.18
# Total penalty : 28 and average penalty : 0.28
# The number of times the organism ate : 17
# Training finished.
#
# Gen :  7
# Episode: 100
# Total time in this generation is : 1875, average time taken per episode of generation is : 18.75
# Total penalty : 37 and average penalty : 0.37
# The number of times the organism ate : 11
# Training finished.
#
# Gen :  8
# Episode: 100
# Total time in this generation is : 1726, average time taken per episode of generation is : 17.26
# Total penalty : 37 and average penalty : 0.37
# The number of times the organism ate : 24
# Training finished.
#
# Gen :  9
# Episode: 100
# Total time in this generation is : 1681, average time taken per episode of generation is : 16.81
# Total penalty : 43 and average penalty : 0.43
# The number of times the organism ate : 30
# Training finished.
#
# Gen :  10
# Episode: 100
# Total time in this generation is : 1738, average time taken per episode of generation is : 17.38
# Total penalty : 54 and average penalty : 0.54
# The number of times the organism ate : 22
# Training finished.
#
# Gen :  11
# Episode: 100
# Total time in this generation is : 1620, average time taken per episode of generation is : 16.2
# Total penalty : 59 and average penalty : 0.59
# The number of times the organism ate : 28
# Training finished.
#
# Gen :  12
# Episode: 100
# Total time in this generation is : 1623, average time taken per episode of generation is : 16.23
# Total penalty : 48 and average penalty : 0.48
# The number of times the organism ate : 29
# Training finished.
#
# Gen :  13
# Episode: 100
# Total time in this generation is : 1598, average time taken per episode of generation is : 15.98
# Total penalty : 56 and average penalty : 0.56
# The number of times the organism ate : 36
# Training finished.
#
# Gen :  14
# Episode: 100
# Total time in this generation is : 1612, average time taken per episode of generation is : 16.12
# Total penalty : 42 and average penalty : 0.42
# The number of times the organism ate : 31
# Training finished.
#
# Gen :  15
# Episode: 100
# Total time in this generation is : 1475, average time taken per episode of generation is : 14.75
# Total penalty : 39 and average penalty : 0.39
# The number of times the organism ate : 42
# Training finished.
#
# Gen :  16
# Episode: 100
# Total time in this generation is : 1639, average time taken per episode of generation is : 16.39
# Total penalty : 44 and average penalty : 0.44
# The number of times the organism ate : 32
# Training finished.
#
# Gen :  17
# Episode: 100
# Total time in this generation is : 1407, average time taken per episode of generation is : 14.07
# Total penalty : 35 and average penalty : 0.35
# The number of times the organism ate : 49
# Training finished.
#
# Gen :  18
# Episode: 100
# Total time in this generation is : 1481, average time taken per episode of generation is : 14.81
# Total penalty : 38 and average penalty : 0.38
# The number of times the organism ate : 44
# Training finished.
#
# Gen :  19
# Episode: 100
# Total time in this generation is : 1527, average time taken per episode of generation is : 15.27
# Total penalty : 35 and average penalty : 0.35
# The number of times the organism ate : 45
# Training finished.
#
# Gen :  20
# Episode: 100
# Total time in this generation is : 1372, average time taken per episode of generation is : 13.72
# Total penalty : 33 and average penalty : 0.33
# The number of times the organism ate : 53
# Training finished.
#
# Gen :  21
# Episode: 100
# Total time in this generation is : 1593, average time taken per episode of generation is : 15.93
# Total penalty : 28 and average penalty : 0.28
# The number of times the organism ate : 35
# Training finished.
#
# Gen :  22
# Episode: 100
# Total time in this generation is : 1469, average time taken per episode of generation is : 14.69
# Total penalty : 25 and average penalty : 0.25
# The number of times the organism ate : 47
# Training finished.
#
# Gen :  23
# Episode: 100
# Total time in this generation is : 1419, average time taken per episode of generation is : 14.19
# Total penalty : 36 and average penalty : 0.36
# The number of times the organism ate : 48
# Training finished.
#
# Gen :  24
# Episode: 100
# Total time in this generation is : 1329, average time taken per episode of generation is : 13.29
# Total penalty : 33 and average penalty : 0.33
# The number of times the organism ate : 60
# Training finished.
#
# Gen :  25
# Episode: 100
# Total time in this generation is : 1405, average time taken per episode of generation is : 14.05
# Total penalty : 30 and average penalty : 0.3
# The number of times the organism ate : 52
# Training finished.

# %%
def print_frames(frames):
    for i, frame in enumerate(frames):
        clear_output(wait=True)
        print(frame['frame'])
        print(f"Timestep: {i + 1}")
        print(f"State: {frame['state']}")
        print(f"Action: {frame['action']}")
        print(f"Reward: {frame['reward']}")
        sleep(.1)

print_frames(frames)
# Out:
# +-------------------+
# |x: | : : : : : : : |
# | : | : : : : | : | |
# | : : : : : : : : : |
# | | : | : : | : :x: |
# |x| : | : : : : : | |
# | : : : : : | : : : |
# | : : : | : | : : : |
# | : | : : | : : : | |
# | : : : : : : : : : |
# | : | : : : : : | :x|
# +-------------------+
#   (East)
#
# Timestep: 1405
# State: 348
# Action: 2
# Reward: -1
