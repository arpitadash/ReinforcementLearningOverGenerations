# %%
import gym

env = gym.make("Taxi-v3").env

env.render()
env.reset() # reset environment to a new, random state
env.render()

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# Action Space Discrete(6)
# State Space Discrete(500)

# %%
state = env.encode(3, 1, 2, 0) # (taxi row, taxi column, passenger index, destination index)
print("State:", state)

env.s = state
env.render()
# Out:
# State: 328
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
import numpy as np
q_table = np.zeros([env.observation_space.n, env.action_space.n])

"""Training the agent"""
print("How many generations ?")
gen = int(input())

import random
from IPython.display import clear_output

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1
for j in range(gen):
    print("Gen : ", j+1)
    time_taken = 0
    total_penalty = 0
    # For plotting metrics
    all_epochs = []
    all_penalties = []
    frames = []
    for i in range(1, 101):
        state = env.reset()

        epochs, penalties, reward, = 0, 0, 0
        done = False

        while not done:
            if random.uniform(0, 1) < epsilon:
                action = env.action_space.sample() # Explore action space
            else:
                action = np.argmax(q_table[state]) # Exploit learned values

            next_state, reward, done, info = env.step(action) 

            old_value = q_table[state, action]
            next_max = np.max(q_table[next_state])

            new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
            q_table[state, action] = new_value

            if reward == -10:
                penalties += 1

            frames.append({
            'frame': env.render(mode='ansi'),
            'state': state,
            'action': action,
            'reward': reward
            }
        )

            state = next_state

            epochs += 1

        if i % 100 == 0:
            print(f"Episode: {i}")
        time_taken += epochs
        total_penalty += penalties
    print(f"Total time in this generation is : {time_taken}, average time taken per episode of generation is : {time_taken/i}")
    print(f"Total penalty : {total_penalty} and average penalty : {total_penalty/100}")
    print("Training finished.\n")

from IPython.display import clear_output
from time import sleep
# Out:
# How many generations ?
# 1000
# Gen :  1
# Episode: 100
# Total time in this generation is : 46788, average time taken per episode of generation is : 467.88
# Total penalty : 2526 and average penalty : 25.26
# Training finished.
#
# Gen :  2
# Episode: 100
# Total time in this generation is : 18828, average time taken per episode of generation is : 188.28
# Total penalty : 664 and average penalty : 6.64
# Training finished.
#
# Gen :  3
# Episode: 100
# Total time in this generation is : 13288, average time taken per episode of generation is : 132.88
# Total penalty : 470 and average penalty : 4.7
# Training finished.
#
# Gen :  4
# Episode: 100
# Total time in this generation is : 9302, average time taken per episode of generation is : 93.02
# Total penalty : 286 and average penalty : 2.86
# Training finished.
#
# Gen :  5
# Episode: 100
# Total time in this generation is : 7765, average time taken per episode of generation is : 77.65
# Total penalty : 251 and average penalty : 2.51
# Training finished.
#
# Gen :  6
# Episode: 100
# Total time in this generation is : 6236, average time taken per episode of generation is : 62.36
# Total penalty : 210 and average penalty : 2.1
# Training finished.
#
# Gen :  7
# Episode: 100
# Total time in this generation is : 5417, average time taken per episode of generation is : 54.17
# Total penalty : 185 and average penalty : 1.85
# Training finished.
#
# Gen :  8
# Episode: 100
# Total time in this generation is : 4707, average time taken per episode of generation is : 47.07
# Total penalty : 156 and average penalty : 1.56
# Training finished.
#
# Gen :  9
# Episode: 100
# Total time in this generation is : 4397, average time taken per episode of generation is : 43.97
# Total penalty : 130 and average penalty : 1.3
# Training finished.
#
# Gen :  10
# Episode: 100
# Total time in this generation is : 4049, average time taken per episode of generation is : 40.49
# Total penalty : 130 and average penalty : 1.3
# Training finished.
#
# Gen :  11
# Episode: 100
# Total time in this generation is : 3067, average time taken per episode of generation is : 30.67
# Total penalty : 107 and average penalty : 1.07
# Training finished.
#
# Gen :  12
# Episode: 100
# Total time in this generation is : 2682, average time taken per episode of generation is : 26.82
# Total penalty : 86 and average penalty : 0.86
# Training finished.
#
# Gen :  13
# Episode: 100
# Total time in this generation is : 2502, average time taken per episode of generation is : 25.02
# Total penalty : 57 and average penalty : 0.57
# Training finished.
#
# Gen :  14
# Episode: 100
# Total time in this generation is : 2655, average time taken per episode of generation is : 26.55
# Total penalty : 86 and average penalty : 0.86
# Training finished.
#
# Gen :  15
# Episode: 100
# Total time in this generation is : 2175, average time taken per episode of generation is : 21.75
# Total penalty : 56 and average penalty : 0.56
# Training finished.
#
# Gen :  16
# Episode: 100
# Total time in this generation is : 2178, average time taken per episode of generation is : 21.78
# Total penalty : 69 and average penalty : 0.69
# Training finished.
#
# Gen :  17
# Episode: 100
# Total time in this generation is : 2093, average time taken per episode of generation is : 20.93
# Total penalty : 68 and average penalty : 0.68
# Training finished.
#
# Gen :  18
# Episode: 100
# Total time in this generation is : 1983, average time taken per episode of generation is : 19.83
# Total penalty : 55 and average penalty : 0.55
# Training finished.
#
# Gen :  19
# Episode: 100
# Total time in this generation is : 2080, average time taken per episode of generation is : 20.8
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  20
# Episode: 100
# Total time in this generation is : 2121, average time taken per episode of generation is : 21.21
# Total penalty : 63 and average penalty : 0.63
# Training finished.
#
# Gen :  21
# Episode: 100
# Total time in this generation is : 1823, average time taken per episode of generation is : 18.23
# Total penalty : 62 and average penalty : 0.62
# Training finished.
#
# Gen :  22
# Episode: 100
# Total time in this generation is : 1929, average time taken per episode of generation is : 19.29
# Total penalty : 73 and average penalty : 0.73
# Training finished.
#
# Gen :  23
# Episode: 100
# Total time in this generation is : 1965, average time taken per episode of generation is : 19.65
# Total penalty : 58 and average penalty : 0.58
# Training finished.
#
# Gen :  24
# Episode: 100
# Total time in this generation is : 1670, average time taken per episode of generation is : 16.7
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  25
# Episode: 100
# Total time in this generation is : 1773, average time taken per episode of generation is : 17.73
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  26
# Episode: 100
# Total time in this generation is : 1809, average time taken per episode of generation is : 18.09
# Total penalty : 58 and average penalty : 0.58
# Training finished.
#
# Gen :  27
# Episode: 100
# Total time in this generation is : 1813, average time taken per episode of generation is : 18.13
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  28
# Episode: 100
# Total time in this generation is : 1704, average time taken per episode of generation is : 17.04
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  29
# Episode: 100
# Total time in this generation is : 1829, average time taken per episode of generation is : 18.29
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  30
# Episode: 100
# Total time in this generation is : 1698, average time taken per episode of generation is : 16.98
# Total penalty : 56 and average penalty : 0.56
# Training finished.
#
# Gen :  31
# Episode: 100
# Total time in this generation is : 1656, average time taken per episode of generation is : 16.56
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  32
# Episode: 100
# Total time in this generation is : 1644, average time taken per episode of generation is : 16.44
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  33
# Episode: 100
# Total time in this generation is : 1650, average time taken per episode of generation is : 16.5
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  34
# Episode: 100
# Total time in this generation is : 1695, average time taken per episode of generation is : 16.95
# Total penalty : 49 and average penalty : 0.49
# Training finished.
#
# Gen :  35
# Episode: 100
# Total time in this generation is : 1736, average time taken per episode of generation is : 17.36
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  36
# Episode: 100
# Total time in this generation is : 1695, average time taken per episode of generation is : 16.95
# Total penalty : 53 and average penalty : 0.53
# Training finished.
#
# Gen :  37
# Episode: 100
# Total time in this generation is : 1527, average time taken per episode of generation is : 15.27
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  38
# Episode: 100
# Total time in this generation is : 1712, average time taken per episode of generation is : 17.12
# Total penalty : 58 and average penalty : 0.58
# Training finished.
#
# Gen :  39
# Episode: 100
# Total time in this generation is : 1665, average time taken per episode of generation is : 16.65
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  40
# Episode: 100
# Total time in this generation is : 1644, average time taken per episode of generation is : 16.44
# Total penalty : 63 and average penalty : 0.63
# Training finished.
#
# Gen :  41
# Episode: 100
# Total time in this generation is : 1633, average time taken per episode of generation is : 16.33
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  42
# Episode: 100
# Total time in this generation is : 1518, average time taken per episode of generation is : 15.18
# Total penalty : 32 and average penalty : 0.32
# Training finished.
#
# Gen :  43
# Episode: 100
# Total time in this generation is : 1600, average time taken per episode of generation is : 16.0
# Total penalty : 38 and average penalty : 0.38
# Training finished.
#
# Gen :  44
# Episode: 100
# Total time in this generation is : 1632, average time taken per episode of generation is : 16.32
# Total penalty : 58 and average penalty : 0.58
# Training finished.
#
# Gen :  45
# Episode: 100
# Total time in this generation is : 1604, average time taken per episode of generation is : 16.04
# Total penalty : 57 and average penalty : 0.57
# Training finished.
#
# Gen :  46
# Episode: 100
# Total time in this generation is : 1592, average time taken per episode of generation is : 15.92
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  47
# Episode: 100
# Total time in this generation is : 1556, average time taken per episode of generation is : 15.56
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  48
# Episode: 100
# Total time in this generation is : 1536, average time taken per episode of generation is : 15.36
# Total penalty : 53 and average penalty : 0.53
# Training finished.
#
# Gen :  49
# Episode: 100
# Total time in this generation is : 1545, average time taken per episode of generation is : 15.45
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  50
# Episode: 100
# Total time in this generation is : 1617, average time taken per episode of generation is : 16.17
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  51
# Episode: 100
# Total time in this generation is : 1558, average time taken per episode of generation is : 15.58
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  52
# Episode: 100
# Total time in this generation is : 1509, average time taken per episode of generation is : 15.09
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  53
# Episode: 100
# Total time in this generation is : 1529, average time taken per episode of generation is : 15.29
# Total penalty : 34 and average penalty : 0.34
# Training finished.
#
# Gen :  54
# Episode: 100
# Total time in this generation is : 1551, average time taken per episode of generation is : 15.51
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  55
# Episode: 100
# Total time in this generation is : 1483, average time taken per episode of generation is : 14.83
# Total penalty : 49 and average penalty : 0.49
# Training finished.
#
# Gen :  56
# Episode: 100
# Total time in this generation is : 1568, average time taken per episode of generation is : 15.68
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  57
# Episode: 100
# Total time in this generation is : 1499, average time taken per episode of generation is : 14.99
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  58
# Episode: 100
# Total time in this generation is : 1486, average time taken per episode of generation is : 14.86
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  59
# Episode: 100
# Total time in this generation is : 1537, average time taken per episode of generation is : 15.37
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  60
# Episode: 100
# Total time in this generation is : 1459, average time taken per episode of generation is : 14.59
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  61
# Episode: 100
# Total time in this generation is : 1502, average time taken per episode of generation is : 15.02
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  62
# Episode: 100
# Total time in this generation is : 1486, average time taken per episode of generation is : 14.86
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  63
# Episode: 100
# Total time in this generation is : 1501, average time taken per episode of generation is : 15.01
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  64
# Episode: 100
# Total time in this generation is : 1488, average time taken per episode of generation is : 14.88
# Total penalty : 31 and average penalty : 0.31
# Training finished.
#
# Gen :  65
# Episode: 100
# Total time in this generation is : 1520, average time taken per episode of generation is : 15.2
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  66
# Episode: 100
# Total time in this generation is : 1504, average time taken per episode of generation is : 15.04
# Total penalty : 32 and average penalty : 0.32
# Training finished.
#
# Gen :  67
# Episode: 100
# Total time in this generation is : 1532, average time taken per episode of generation is : 15.32
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  68
# Episode: 100
# Total time in this generation is : 1467, average time taken per episode of generation is : 14.67
# Total penalty : 56 and average penalty : 0.56
# Training finished.
#
# Gen :  69
# Episode: 100
# Total time in this generation is : 1483, average time taken per episode of generation is : 14.83
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  70
# Episode: 100
# Total time in this generation is : 1510, average time taken per episode of generation is : 15.1
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  71
# Episode: 100
# Total time in this generation is : 1495, average time taken per episode of generation is : 14.95
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  72
# Episode: 100
# Total time in this generation is : 1512, average time taken per episode of generation is : 15.12
# Total penalty : 53 and average penalty : 0.53
# Training finished.
#
# Gen :  73
# Episode: 100
# Total time in this generation is : 1530, average time taken per episode of generation is : 15.3
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  74
# Episode: 100
# Total time in this generation is : 1570, average time taken per episode of generation is : 15.7
# Total penalty : 53 and average penalty : 0.53
# Training finished.
#
# Gen :  75
# Episode: 100
# Total time in this generation is : 1470, average time taken per episode of generation is : 14.7
# Total penalty : 38 and average penalty : 0.38
# Training finished.
#
# Gen :  76
# Episode: 100
# Total time in this generation is : 1459, average time taken per episode of generation is : 14.59
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  77
# Episode: 100
# Total time in this generation is : 1505, average time taken per episode of generation is : 15.05
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  78
# Episode: 100
# Total time in this generation is : 1489, average time taken per episode of generation is : 14.89
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  79
# Episode: 100
# Total time in this generation is : 1527, average time taken per episode of generation is : 15.27
# Total penalty : 60 and average penalty : 0.6
# Training finished.
#
# Gen :  80
# Episode: 100
# Total time in this generation is : 1491, average time taken per episode of generation is : 14.91
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  81
# Episode: 100
# Total time in this generation is : 1454, average time taken per episode of generation is : 14.54
# Total penalty : 35 and average penalty : 0.35
# Training finished.
#
# Gen :  82
# Episode: 100
# Total time in this generation is : 1446, average time taken per episode of generation is : 14.46
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  83
# Episode: 100
# Total time in this generation is : 1500, average time taken per episode of generation is : 15.0
# Total penalty : 54 and average penalty : 0.54
# Training finished.
#
# Gen :  84
# Episode: 100
# Total time in this generation is : 1483, average time taken per episode of generation is : 14.83
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  85
# Episode: 100
# Total time in this generation is : 1512, average time taken per episode of generation is : 15.12
# Total penalty : 25 and average penalty : 0.25
# Training finished.
#
# Gen :  86
# Episode: 100
# Total time in this generation is : 1496, average time taken per episode of generation is : 14.96
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  87
# Episode: 100
# Total time in this generation is : 1513, average time taken per episode of generation is : 15.13
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  88
# Episode: 100
# Total time in this generation is : 1513, average time taken per episode of generation is : 15.13
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  89
# Episode: 100
# Total time in this generation is : 1481, average time taken per episode of generation is : 14.81
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  90
# Episode: 100
# Total time in this generation is : 1448, average time taken per episode of generation is : 14.48
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  91
# Episode: 100
# Total time in this generation is : 1431, average time taken per episode of generation is : 14.31
# Total penalty : 31 and average penalty : 0.31
# Training finished.
#
# Gen :  92
# Episode: 100
# Total time in this generation is : 1496, average time taken per episode of generation is : 14.96
# Total penalty : 61 and average penalty : 0.61
# Training finished.
#
# Gen :  93
# Episode: 100
# Total time in this generation is : 1555, average time taken per episode of generation is : 15.55
# Total penalty : 49 and average penalty : 0.49
# Training finished.
#
# Gen :  94
# Episode: 100
# Total time in this generation is : 1536, average time taken per episode of generation is : 15.36
# Total penalty : 57 and average penalty : 0.57
# Training finished.
#
# Gen :  95
# Episode: 100
# Total time in this generation is : 1474, average time taken per episode of generation is : 14.74
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  96
# Episode: 100
# Total time in this generation is : 1491, average time taken per episode of generation is : 14.91
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  97
# Episode: 100
# Total time in this generation is : 1479, average time taken per episode of generation is : 14.79
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  98
# Episode: 100
# Total time in this generation is : 1484, average time taken per episode of generation is : 14.84
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  99
# Episode: 100
# Total time in this generation is : 1494, average time taken per episode of generation is : 14.94
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  100
# Episode: 100
# Total time in this generation is : 1508, average time taken per episode of generation is : 15.08
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  101
# Episode: 100
# Total time in this generation is : 1492, average time taken per episode of generation is : 14.92
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  102
# Episode: 100
# Total time in this generation is : 1527, average time taken per episode of generation is : 15.27
# Total penalty : 58 and average penalty : 0.58
# Training finished.
#
# Gen :  103
# Episode: 100
# Total time in this generation is : 1542, average time taken per episode of generation is : 15.42
# Total penalty : 54 and average penalty : 0.54
# Training finished.
#
# Gen :  104
# Episode: 100
# Total time in this generation is : 1495, average time taken per episode of generation is : 14.95
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  105
# Episode: 100
# Total time in this generation is : 1478, average time taken per episode of generation is : 14.78
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  106
# Episode: 100
# Total time in this generation is : 1500, average time taken per episode of generation is : 15.0
# Total penalty : 30 and average penalty : 0.3
# Training finished.
#
# Gen :  107
# Episode: 100
# Total time in this generation is : 1525, average time taken per episode of generation is : 15.25
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  108
# Episode: 100
# Total time in this generation is : 1421, average time taken per episode of generation is : 14.21
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  109
# Episode: 100
# Total time in this generation is : 1419, average time taken per episode of generation is : 14.19
# Total penalty : 35 and average penalty : 0.35
# Training finished.
#
# Gen :  110
# Episode: 100
# Total time in this generation is : 1495, average time taken per episode of generation is : 14.95
# Total penalty : 34 and average penalty : 0.34
# Training finished.
#
# Gen :  111
# Episode: 100
# Total time in this generation is : 1549, average time taken per episode of generation is : 15.49
# Total penalty : 61 and average penalty : 0.61
# Training finished.
#
# Gen :  112
# Episode: 100
# Total time in this generation is : 1565, average time taken per episode of generation is : 15.65
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  113
# Episode: 100
# Total time in this generation is : 1497, average time taken per episode of generation is : 14.97
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  114
# Episode: 100
# Total time in this generation is : 1460, average time taken per episode of generation is : 14.6
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  115
# Episode: 100
# Total time in this generation is : 1466, average time taken per episode of generation is : 14.66
# Total penalty : 29 and average penalty : 0.29
# Training finished.
#
# Gen :  116
# Episode: 100
# Total time in this generation is : 1525, average time taken per episode of generation is : 15.25
# Total penalty : 57 and average penalty : 0.57
# Training finished.
#
# Gen :  117
# Episode: 100
# Total time in this generation is : 1550, average time taken per episode of generation is : 15.5
# Total penalty : 34 and average penalty : 0.34
# Training finished.
#
# Gen :  118
# Episode: 100
# Total time in this generation is : 1438, average time taken per episode of generation is : 14.38
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  119
# Episode: 100
# Total time in this generation is : 1467, average time taken per episode of generation is : 14.67
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  120
# Episode: 100
# Total time in this generation is : 1475, average time taken per episode of generation is : 14.75
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  121
# Episode: 100
# Total time in this generation is : 1508, average time taken per episode of generation is : 15.08
# Total penalty : 61 and average penalty : 0.61
# Training finished.
#
# Gen :  122
# Episode: 100
# Total time in this generation is : 1567, average time taken per episode of generation is : 15.67
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  123
# Episode: 100
# Total time in this generation is : 1438, average time taken per episode of generation is : 14.38
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  124
# Episode: 100
# Total time in this generation is : 1518, average time taken per episode of generation is : 15.18
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  125
# Episode: 100
# Total time in this generation is : 1451, average time taken per episode of generation is : 14.51
# Total penalty : 34 and average penalty : 0.34
# Training finished.
#
# Gen :  126
# Episode: 100
# Total time in this generation is : 1477, average time taken per episode of generation is : 14.77
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  127
# Episode: 100
# Total time in this generation is : 1426, average time taken per episode of generation is : 14.26
# Total penalty : 32 and average penalty : 0.32
# Training finished.
#
# Gen :  128
# Episode: 100
# Total time in this generation is : 1445, average time taken per episode of generation is : 14.45
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  129
# Episode: 100
# Total time in this generation is : 1505, average time taken per episode of generation is : 15.05
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  130
# Episode: 100
# Total time in this generation is : 1476, average time taken per episode of generation is : 14.76
# Total penalty : 31 and average penalty : 0.31
# Training finished.
#
# Gen :  131
# Episode: 100
# Total time in this generation is : 1471, average time taken per episode of generation is : 14.71
# Total penalty : 36 and average penalty : 0.36
# Training finished.
#
# Gen :  132
# Episode: 100
# Total time in this generation is : 1507, average time taken per episode of generation is : 15.07
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  133
# Episode: 100
# Total time in this generation is : 1469, average time taken per episode of generation is : 14.69
# Total penalty : 66 and average penalty : 0.66
# Training finished.
#
# Gen :  134
# Episode: 100
# Total time in this generation is : 1497, average time taken per episode of generation is : 14.97
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  135
# Episode: 100
# Total time in this generation is : 1444, average time taken per episode of generation is : 14.44
# Total penalty : 36 and average penalty : 0.36
# Training finished.
#
# Gen :  136
# Episode: 100
# Total time in this generation is : 1439, average time taken per episode of generation is : 14.39
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  137
# Episode: 100
# Total time in this generation is : 1539, average time taken per episode of generation is : 15.39
# Total penalty : 54 and average penalty : 0.54
# Training finished.
#
# Gen :  138
# Episode: 100
# Total time in this generation is : 1496, average time taken per episode of generation is : 14.96
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  139
# Episode: 100
# Total time in this generation is : 1521, average time taken per episode of generation is : 15.21
# Total penalty : 60 and average penalty : 0.6
# Training finished.
#
# Gen :  140
# Episode: 100
# Total time in this generation is : 1469, average time taken per episode of generation is : 14.69
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  141
# Episode: 100
# Total time in this generation is : 1471, average time taken per episode of generation is : 14.71
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  142
# Episode: 100
# Total time in this generation is : 1474, average time taken per episode of generation is : 14.74
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  143
# Episode: 100
# Total time in this generation is : 1475, average time taken per episode of generation is : 14.75
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  144
# Episode: 100
# Total time in this generation is : 1544, average time taken per episode of generation is : 15.44
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  145
# Episode: 100
# Total time in this generation is : 1569, average time taken per episode of generation is : 15.69
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  146
# Episode: 100
# Total time in this generation is : 1462, average time taken per episode of generation is : 14.62
# Total penalty : 38 and average penalty : 0.38
# Training finished.
#
# Gen :  147
# Episode: 100
# Total time in this generation is : 1498, average time taken per episode of generation is : 14.98
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  148
# Episode: 100
# Total time in this generation is : 1463, average time taken per episode of generation is : 14.63
# Total penalty : 54 and average penalty : 0.54
# Training finished.
#
# Gen :  149
# Episode: 100
# Total time in this generation is : 1498, average time taken per episode of generation is : 14.98
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  150
# Episode: 100
# Total time in this generation is : 1521, average time taken per episode of generation is : 15.21
# Total penalty : 58 and average penalty : 0.58
# Training finished.
#
# Gen :  151
# Episode: 100
# Total time in this generation is : 1474, average time taken per episode of generation is : 14.74
# Total penalty : 35 and average penalty : 0.35
# Training finished.
#
# Gen :  152
# Episode: 100
# Total time in this generation is : 1443, average time taken per episode of generation is : 14.43
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  153
# Episode: 100
# Total time in this generation is : 1477, average time taken per episode of generation is : 14.77
# Total penalty : 58 and average penalty : 0.58
# Training finished.
#
# Gen :  154
# Episode: 100
# Total time in this generation is : 1436, average time taken per episode of generation is : 14.36
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  155
# Episode: 100
# Total time in this generation is : 1508, average time taken per episode of generation is : 15.08
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  156
# Episode: 100
# Total time in this generation is : 1435, average time taken per episode of generation is : 14.35
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  157
# Episode: 100
# Total time in this generation is : 1437, average time taken per episode of generation is : 14.37
# Total penalty : 27 and average penalty : 0.27
# Training finished.
#
# Gen :  158
# Episode: 100
# Total time in this generation is : 1502, average time taken per episode of generation is : 15.02
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  159
# Episode: 100
# Total time in this generation is : 1389, average time taken per episode of generation is : 13.89
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  160
# Episode: 100
# Total time in this generation is : 1464, average time taken per episode of generation is : 14.64
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  161
# Episode: 100
# Total time in this generation is : 1426, average time taken per episode of generation is : 14.26
# Total penalty : 36 and average penalty : 0.36
# Training finished.
#
# Gen :  162
# Episode: 100
# Total time in this generation is : 1476, average time taken per episode of generation is : 14.76
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  163
# Episode: 100
# Total time in this generation is : 1490, average time taken per episode of generation is : 14.9
# Total penalty : 38 and average penalty : 0.38
# Training finished.
#
# Gen :  164
# Episode: 100
# Total time in this generation is : 1498, average time taken per episode of generation is : 14.98
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  165
# Episode: 100
# Total time in this generation is : 1424, average time taken per episode of generation is : 14.24
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  166
# Episode: 100
# Total time in this generation is : 1512, average time taken per episode of generation is : 15.12
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  167
# Episode: 100
# Total time in this generation is : 1465, average time taken per episode of generation is : 14.65
# Total penalty : 30 and average penalty : 0.3
# Training finished.
#
# Gen :  168
# Episode: 100
# Total time in this generation is : 1455, average time taken per episode of generation is : 14.55
# Total penalty : 32 and average penalty : 0.32
# Training finished.
#
# Gen :  169
# Episode: 100
# Total time in this generation is : 1476, average time taken per episode of generation is : 14.76
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  170
# Episode: 100
# Total time in this generation is : 1481, average time taken per episode of generation is : 14.81
# Total penalty : 31 and average penalty : 0.31
# Training finished.
#
# Gen :  171
# Episode: 100
# Total time in this generation is : 1499, average time taken per episode of generation is : 14.99
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  172
# Episode: 100
# Total time in this generation is : 1467, average time taken per episode of generation is : 14.67
# Total penalty : 32 and average penalty : 0.32
# Training finished.
#
# Gen :  173
# Episode: 100
# Total time in this generation is : 1500, average time taken per episode of generation is : 15.0
# Total penalty : 53 and average penalty : 0.53
# Training finished.
#
# Gen :  174
# Episode: 100
# Total time in this generation is : 1454, average time taken per episode of generation is : 14.54
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  175
# Episode: 100
# Total time in this generation is : 1514, average time taken per episode of generation is : 15.14
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  176
# Episode: 100
# Total time in this generation is : 1515, average time taken per episode of generation is : 15.15
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  177
# Episode: 100
# Total time in this generation is : 1451, average time taken per episode of generation is : 14.51
# Total penalty : 31 and average penalty : 0.31
# Training finished.
#
# Gen :  178
# Episode: 100
# Total time in this generation is : 1438, average time taken per episode of generation is : 14.38
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  179
# Episode: 100
# Total time in this generation is : 1464, average time taken per episode of generation is : 14.64
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  180
# Episode: 100
# Total time in this generation is : 1437, average time taken per episode of generation is : 14.37
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  181
# Episode: 100
# Total time in this generation is : 1500, average time taken per episode of generation is : 15.0
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  182
# Episode: 100
# Total time in this generation is : 1519, average time taken per episode of generation is : 15.19
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  183
# Episode: 100
# Total time in this generation is : 1468, average time taken per episode of generation is : 14.68
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  184
# Episode: 100
# Total time in this generation is : 1471, average time taken per episode of generation is : 14.71
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  185
# Episode: 100
# Total time in this generation is : 1457, average time taken per episode of generation is : 14.57
# Total penalty : 35 and average penalty : 0.35
# Training finished.
#
# Gen :  186
# Episode: 100
# Total time in this generation is : 1462, average time taken per episode of generation is : 14.62
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  187
# Episode: 100
# Total time in this generation is : 1481, average time taken per episode of generation is : 14.81
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  188
# Episode: 100
# Total time in this generation is : 1468, average time taken per episode of generation is : 14.68
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  189
# Episode: 100
# Total time in this generation is : 1439, average time taken per episode of generation is : 14.39
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  190
# Episode: 100
# Total time in this generation is : 1479, average time taken per episode of generation is : 14.79
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  191
# Episode: 100
# Total time in this generation is : 1446, average time taken per episode of generation is : 14.46
# Total penalty : 53 and average penalty : 0.53
# Training finished.
#
# Gen :  192
# Episode: 100
# Total time in this generation is : 1435, average time taken per episode of generation is : 14.35
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  193
# Episode: 100
# Total time in this generation is : 1499, average time taken per episode of generation is : 14.99
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  194
# Episode: 100
# Total time in this generation is : 1453, average time taken per episode of generation is : 14.53
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  195
# Episode: 100
# Total time in this generation is : 1463, average time taken per episode of generation is : 14.63
# Total penalty : 60 and average penalty : 0.6
# Training finished.
#
# Gen :  196
# Episode: 100
# Total time in this generation is : 1476, average time taken per episode of generation is : 14.76
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  197
# Episode: 100
# Total time in this generation is : 1503, average time taken per episode of generation is : 15.03
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  198
# Episode: 100
# Total time in this generation is : 1481, average time taken per episode of generation is : 14.81
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  199
# Episode: 100
# Total time in this generation is : 1417, average time taken per episode of generation is : 14.17
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  200
# Episode: 100
# Total time in this generation is : 1453, average time taken per episode of generation is : 14.53
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  201
# Episode: 100
# Total time in this generation is : 1518, average time taken per episode of generation is : 15.18
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  202
# Episode: 100
# Total time in this generation is : 1485, average time taken per episode of generation is : 14.85
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  203
# Episode: 100
# Total time in this generation is : 1489, average time taken per episode of generation is : 14.89
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  204
# Episode: 100
# Total time in this generation is : 1485, average time taken per episode of generation is : 14.85
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  205
# Episode: 100
# Total time in this generation is : 1488, average time taken per episode of generation is : 14.88
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  206
# Episode: 100
# Total time in this generation is : 1496, average time taken per episode of generation is : 14.96
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  207
# Episode: 100
# Total time in this generation is : 1540, average time taken per episode of generation is : 15.4
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  208
# Episode: 100
# Total time in this generation is : 1439, average time taken per episode of generation is : 14.39
# Total penalty : 26 and average penalty : 0.26
# Training finished.
#
# Gen :  209
# Episode: 100
# Total time in this generation is : 1530, average time taken per episode of generation is : 15.3
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  210
# Episode: 100
# Total time in this generation is : 1455, average time taken per episode of generation is : 14.55
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  211
# Episode: 100
# Total time in this generation is : 1478, average time taken per episode of generation is : 14.78
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  212
# Episode: 100
# Total time in this generation is : 1469, average time taken per episode of generation is : 14.69
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  213
# Episode: 100
# Total time in this generation is : 1525, average time taken per episode of generation is : 15.25
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  214
# Episode: 100
# Total time in this generation is : 1420, average time taken per episode of generation is : 14.2
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  215
# Episode: 100
# Total time in this generation is : 1487, average time taken per episode of generation is : 14.87
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  216
# Episode: 100
# Total time in this generation is : 1486, average time taken per episode of generation is : 14.86
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  217
# Episode: 100
# Total time in this generation is : 1499, average time taken per episode of generation is : 14.99
# Total penalty : 57 and average penalty : 0.57
# Training finished.
#
# Gen :  218
# Episode: 100
# Total time in this generation is : 1473, average time taken per episode of generation is : 14.73
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  219
# Episode: 100
# Total time in this generation is : 1442, average time taken per episode of generation is : 14.42
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  220
# Episode: 100
# Total time in this generation is : 1493, average time taken per episode of generation is : 14.93
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  221
# Episode: 100
# Total time in this generation is : 1376, average time taken per episode of generation is : 13.76
# Total penalty : 27 and average penalty : 0.27
# Training finished.
#
# Gen :  222
# Episode: 100
# Total time in this generation is : 1479, average time taken per episode of generation is : 14.79
# Total penalty : 53 and average penalty : 0.53
# Training finished.
#
# Gen :  223
# Episode: 100
# Total time in this generation is : 1510, average time taken per episode of generation is : 15.1
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  224
# Episode: 100
# Total time in this generation is : 1449, average time taken per episode of generation is : 14.49
# Total penalty : 33 and average penalty : 0.33
# Training finished.
#
# Gen :  225
# Episode: 100
# Total time in this generation is : 1474, average time taken per episode of generation is : 14.74
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  226
# Episode: 100
# Total time in this generation is : 1498, average time taken per episode of generation is : 14.98
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  227
# Episode: 100
# Total time in this generation is : 1524, average time taken per episode of generation is : 15.24
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  228
# Episode: 100
# Total time in this generation is : 1485, average time taken per episode of generation is : 14.85
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  229
# Episode: 100
# Total time in this generation is : 1474, average time taken per episode of generation is : 14.74
# Total penalty : 57 and average penalty : 0.57
# Training finished.
#
# Gen :  230
# Episode: 100
# Total time in this generation is : 1480, average time taken per episode of generation is : 14.8
# Total penalty : 59 and average penalty : 0.59
# Training finished.
#
# Gen :  231
# Episode: 100
# Total time in this generation is : 1456, average time taken per episode of generation is : 14.56
# Total penalty : 31 and average penalty : 0.31
# Training finished.
#
# Gen :  232
# Episode: 100
# Total time in this generation is : 1479, average time taken per episode of generation is : 14.79
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  233
# Episode: 100
# Total time in this generation is : 1473, average time taken per episode of generation is : 14.73
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  234
# Episode: 100
# Total time in this generation is : 1479, average time taken per episode of generation is : 14.79
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  235
# Episode: 100
# Total time in this generation is : 1470, average time taken per episode of generation is : 14.7
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  236
# Episode: 100
# Total time in this generation is : 1437, average time taken per episode of generation is : 14.37
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  237
# Episode: 100
# Total time in this generation is : 1483, average time taken per episode of generation is : 14.83
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  238
# Episode: 100
# Total time in this generation is : 1421, average time taken per episode of generation is : 14.21
# Total penalty : 38 and average penalty : 0.38
# Training finished.
#
# Gen :  239
# Episode: 100
# Total time in this generation is : 1502, average time taken per episode of generation is : 15.02
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  240
# Episode: 100
# Total time in this generation is : 1508, average time taken per episode of generation is : 15.08
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  241
# Episode: 100
# Total time in this generation is : 1477, average time taken per episode of generation is : 14.77
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  242
# Episode: 100
# Total time in this generation is : 1455, average time taken per episode of generation is : 14.55
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  243
# Episode: 100
# Total time in this generation is : 1486, average time taken per episode of generation is : 14.86
# Total penalty : 49 and average penalty : 0.49
# Training finished.
#
# Gen :  244
# Episode: 100
# Total time in this generation is : 1458, average time taken per episode of generation is : 14.58
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  245
# Episode: 100
# Total time in this generation is : 1395, average time taken per episode of generation is : 13.95
# Total penalty : 34 and average penalty : 0.34
# Training finished.
#
# Gen :  246
# Episode: 100
# Total time in this generation is : 1465, average time taken per episode of generation is : 14.65
# Total penalty : 55 and average penalty : 0.55
# Training finished.
#
# Gen :  247
# Episode: 100
# Total time in this generation is : 1469, average time taken per episode of generation is : 14.69
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  248
# Episode: 100
# Total time in this generation is : 1436, average time taken per episode of generation is : 14.36
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  249
# Episode: 100
# Total time in this generation is : 1518, average time taken per episode of generation is : 15.18
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  250
# Episode: 100
# Total time in this generation is : 1441, average time taken per episode of generation is : 14.41
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  251
# Episode: 100
# Total time in this generation is : 1501, average time taken per episode of generation is : 15.01
# Total penalty : 58 and average penalty : 0.58
# Training finished.
#
# Gen :  252
# Episode: 100
# Total time in this generation is : 1489, average time taken per episode of generation is : 14.89
# Total penalty : 54 and average penalty : 0.54
# Training finished.
#
# Gen :  253
# Episode: 100
# Total time in this generation is : 1436, average time taken per episode of generation is : 14.36
# Total penalty : 31 and average penalty : 0.31
# Training finished.
#
# Gen :  254
# Episode: 100
# Total time in this generation is : 1409, average time taken per episode of generation is : 14.09
# Total penalty : 54 and average penalty : 0.54
# Training finished.
#
# Gen :  255
# Episode: 100
# Total time in this generation is : 1466, average time taken per episode of generation is : 14.66
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  256
# Episode: 100
# Total time in this generation is : 1469, average time taken per episode of generation is : 14.69
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  257
# Episode: 100
# Total time in this generation is : 1520, average time taken per episode of generation is : 15.2
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  258
# Episode: 100
# ...
# Total penalty : 30 and average penalty : 0.3
# Training finished.
#
# Gen :  916
# Episode: 100
# Total time in this generation is : 1461, average time taken per episode of generation is : 14.61
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  917
# Episode: 100
# Total time in this generation is : 1454, average time taken per episode of generation is : 14.54
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  918
# Episode: 100
# Total time in this generation is : 1371, average time taken per episode of generation is : 13.71
# Total penalty : 32 and average penalty : 0.32
# Training finished.
#
# Gen :  919
# Episode: 100
# Total time in this generation is : 1476, average time taken per episode of generation is : 14.76
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  920
# Episode: 100
# Total time in this generation is : 1511, average time taken per episode of generation is : 15.11
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  921
# Episode: 100
# Total time in this generation is : 1495, average time taken per episode of generation is : 14.95
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  922
# Episode: 100
# Total time in this generation is : 1470, average time taken per episode of generation is : 14.7
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  923
# Episode: 100
# Total time in this generation is : 1481, average time taken per episode of generation is : 14.81
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  924
# Episode: 100
# Total time in this generation is : 1475, average time taken per episode of generation is : 14.75
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  925
# Episode: 100
# Total time in this generation is : 1420, average time taken per episode of generation is : 14.2
# Total penalty : 32 and average penalty : 0.32
# Training finished.
#
# Gen :  926
# Episode: 100
# Total time in this generation is : 1487, average time taken per episode of generation is : 14.87
# Total penalty : 34 and average penalty : 0.34
# Training finished.
#
# Gen :  927
# Episode: 100
# Total time in this generation is : 1465, average time taken per episode of generation is : 14.65
# Total penalty : 32 and average penalty : 0.32
# Training finished.
#
# Gen :  928
# Episode: 100
# Total time in this generation is : 1507, average time taken per episode of generation is : 15.07
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  929
# Episode: 100
# Total time in this generation is : 1477, average time taken per episode of generation is : 14.77
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  930
# Episode: 100
# Total time in this generation is : 1486, average time taken per episode of generation is : 14.86
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  931
# Episode: 100
# Total time in this generation is : 1449, average time taken per episode of generation is : 14.49
# Total penalty : 36 and average penalty : 0.36
# Training finished.
#
# Gen :  932
# Episode: 100
# Total time in this generation is : 1488, average time taken per episode of generation is : 14.88
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  933
# Episode: 100
# Total time in this generation is : 1429, average time taken per episode of generation is : 14.29
# Total penalty : 40 and average penalty : 0.4
# Training finished.
#
# Gen :  934
# Episode: 100
# Total time in this generation is : 1472, average time taken per episode of generation is : 14.72
# Total penalty : 27 and average penalty : 0.27
# Training finished.
#
# Gen :  935
# Episode: 100
# Total time in this generation is : 1481, average time taken per episode of generation is : 14.81
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  936
# Episode: 100
# Total time in this generation is : 1483, average time taken per episode of generation is : 14.83
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  937
# Episode: 100
# Total time in this generation is : 1472, average time taken per episode of generation is : 14.72
# Total penalty : 38 and average penalty : 0.38
# Training finished.
#
# Gen :  938
# Episode: 100
# Total time in this generation is : 1425, average time taken per episode of generation is : 14.25
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  939
# Episode: 100
# Total time in this generation is : 1474, average time taken per episode of generation is : 14.74
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  940
# Episode: 100
# Total time in this generation is : 1490, average time taken per episode of generation is : 14.9
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  941
# Episode: 100
# Total time in this generation is : 1444, average time taken per episode of generation is : 14.44
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  942
# Episode: 100
# Total time in this generation is : 1437, average time taken per episode of generation is : 14.37
# Total penalty : 54 and average penalty : 0.54
# Training finished.
#
# Gen :  943
# Episode: 100
# Total time in this generation is : 1479, average time taken per episode of generation is : 14.79
# Total penalty : 38 and average penalty : 0.38
# Training finished.
#
# Gen :  944
# Episode: 100
# Total time in this generation is : 1477, average time taken per episode of generation is : 14.77
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  945
# Episode: 100
# Total time in this generation is : 1419, average time taken per episode of generation is : 14.19
# Total penalty : 54 and average penalty : 0.54
# Training finished.
#
# Gen :  946
# Episode: 100
# Total time in this generation is : 1468, average time taken per episode of generation is : 14.68
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  947
# Episode: 100
# Total time in this generation is : 1428, average time taken per episode of generation is : 14.28
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  948
# Episode: 100
# Total time in this generation is : 1487, average time taken per episode of generation is : 14.87
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  949
# Episode: 100
# Total time in this generation is : 1435, average time taken per episode of generation is : 14.35
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  950
# Episode: 100
# Total time in this generation is : 1454, average time taken per episode of generation is : 14.54
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  951
# Episode: 100
# Total time in this generation is : 1413, average time taken per episode of generation is : 14.13
# Total penalty : 50 and average penalty : 0.5
# Training finished.
#
# Gen :  952
# Episode: 100
# Total time in this generation is : 1405, average time taken per episode of generation is : 14.05
# Total penalty : 34 and average penalty : 0.34
# Training finished.
#
# Gen :  953
# Episode: 100
# Total time in this generation is : 1478, average time taken per episode of generation is : 14.78
# Total penalty : 33 and average penalty : 0.33
# Training finished.
#
# Gen :  954
# Episode: 100
# Total time in this generation is : 1490, average time taken per episode of generation is : 14.9
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  955
# Episode: 100
# Total time in this generation is : 1478, average time taken per episode of generation is : 14.78
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  956
# Episode: 100
# Total time in this generation is : 1442, average time taken per episode of generation is : 14.42
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  957
# Episode: 100
# Total time in this generation is : 1463, average time taken per episode of generation is : 14.63
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  958
# Episode: 100
# Total time in this generation is : 1470, average time taken per episode of generation is : 14.7
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  959
# Episode: 100
# Total time in this generation is : 1514, average time taken per episode of generation is : 15.14
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  960
# Episode: 100
# Total time in this generation is : 1478, average time taken per episode of generation is : 14.78
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  961
# Episode: 100
# Total time in this generation is : 1482, average time taken per episode of generation is : 14.82
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  962
# Episode: 100
# Total time in this generation is : 1443, average time taken per episode of generation is : 14.43
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  963
# Episode: 100
# Total time in this generation is : 1456, average time taken per episode of generation is : 14.56
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  964
# Episode: 100
# Total time in this generation is : 1441, average time taken per episode of generation is : 14.41
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  965
# Episode: 100
# Total time in this generation is : 1459, average time taken per episode of generation is : 14.59
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  966
# Episode: 100
# Total time in this generation is : 1391, average time taken per episode of generation is : 13.91
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  967
# Episode: 100
# Total time in this generation is : 1455, average time taken per episode of generation is : 14.55
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  968
# Episode: 100
# Total time in this generation is : 1505, average time taken per episode of generation is : 15.05
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  969
# Episode: 100
# Total time in this generation is : 1497, average time taken per episode of generation is : 14.97
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  970
# Episode: 100
# Total time in this generation is : 1513, average time taken per episode of generation is : 15.13
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  971
# Episode: 100
# Total time in this generation is : 1442, average time taken per episode of generation is : 14.42
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  972
# Episode: 100
# Total time in this generation is : 1514, average time taken per episode of generation is : 15.14
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  973
# Episode: 100
# Total time in this generation is : 1505, average time taken per episode of generation is : 15.05
# Total penalty : 60 and average penalty : 0.6
# Training finished.
#
# Gen :  974
# Episode: 100
# Total time in this generation is : 1469, average time taken per episode of generation is : 14.69
# Total penalty : 65 and average penalty : 0.65
# Training finished.
#
# Gen :  975
# Episode: 100
# Total time in this generation is : 1495, average time taken per episode of generation is : 14.95
# Total penalty : 51 and average penalty : 0.51
# Training finished.
#
# Gen :  976
# Episode: 100
# Total time in this generation is : 1493, average time taken per episode of generation is : 14.93
# Total penalty : 55 and average penalty : 0.55
# Training finished.
#
# Gen :  977
# Episode: 100
# Total time in this generation is : 1452, average time taken per episode of generation is : 14.52
# Total penalty : 39 and average penalty : 0.39
# Training finished.
#
# Gen :  978
# Episode: 100
# Total time in this generation is : 1549, average time taken per episode of generation is : 15.49
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  979
# Episode: 100
# Total time in this generation is : 1480, average time taken per episode of generation is : 14.8
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  980
# Episode: 100
# Total time in this generation is : 1574, average time taken per episode of generation is : 15.74
# Total penalty : 55 and average penalty : 0.55
# Training finished.
#
# Gen :  981
# Episode: 100
# Total time in this generation is : 1490, average time taken per episode of generation is : 14.9
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  982
# Episode: 100
# Total time in this generation is : 1490, average time taken per episode of generation is : 14.9
# Total penalty : 41 and average penalty : 0.41
# Training finished.
#
# Gen :  983
# Episode: 100
# Total time in this generation is : 1524, average time taken per episode of generation is : 15.24
# Total penalty : 43 and average penalty : 0.43
# Training finished.
#
# Gen :  984
# Episode: 100
# Total time in this generation is : 1466, average time taken per episode of generation is : 14.66
# Total penalty : 35 and average penalty : 0.35
# Training finished.
#
# Gen :  985
# Episode: 100
# Total time in this generation is : 1433, average time taken per episode of generation is : 14.33
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  986
# Episode: 100
# Total time in this generation is : 1531, average time taken per episode of generation is : 15.31
# Total penalty : 44 and average penalty : 0.44
# Training finished.
#
# Gen :  987
# Episode: 100
# Total time in this generation is : 1513, average time taken per episode of generation is : 15.13
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  988
# Episode: 100
# Total time in this generation is : 1471, average time taken per episode of generation is : 14.71
# Total penalty : 42 and average penalty : 0.42
# Training finished.
#
# Gen :  989
# Episode: 100
# Total time in this generation is : 1558, average time taken per episode of generation is : 15.58
# Total penalty : 49 and average penalty : 0.49
# Training finished.
#
# Gen :  990
# Episode: 100
# Total time in this generation is : 1529, average time taken per episode of generation is : 15.29
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  991
# Episode: 100
# Total time in this generation is : 1471, average time taken per episode of generation is : 14.71
# Total penalty : 47 and average penalty : 0.47
# Training finished.
#
# Gen :  992
# Episode: 100
# Total time in this generation is : 1461, average time taken per episode of generation is : 14.61
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  993
# Episode: 100
# Total time in this generation is : 1498, average time taken per episode of generation is : 14.98
# Total penalty : 53 and average penalty : 0.53
# Training finished.
#
# Gen :  994
# Episode: 100
# Total time in this generation is : 1480, average time taken per episode of generation is : 14.8
# Total penalty : 48 and average penalty : 0.48
# Training finished.
#
# Gen :  995
# Episode: 100
# Total time in this generation is : 1508, average time taken per episode of generation is : 15.08
# Total penalty : 37 and average penalty : 0.37
# Training finished.
#
# Gen :  996
# Episode: 100
# Total time in this generation is : 1470, average time taken per episode of generation is : 14.7
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  997
# Episode: 100
# Total time in this generation is : 1457, average time taken per episode of generation is : 14.57
# Total penalty : 46 and average penalty : 0.46
# Training finished.
#
# Gen :  998
# Episode: 100
# Total time in this generation is : 1523, average time taken per episode of generation is : 15.23
# Total penalty : 45 and average penalty : 0.45
# Training finished.
#
# Gen :  999
# Episode: 100
# Total time in this generation is : 1453, average time taken per episode of generation is : 14.53
# Total penalty : 52 and average penalty : 0.52
# Training finished.
#
# Gen :  1000
# Episode: 100
# Total time in this generation is : 1485, average time taken per episode of generation is : 14.85
# Total penalty : 48 and average penalty : 0.48
# Training finished.

# %%
"""Evaluate agent's performance after Q-learning"""

total_epochs, total_penalties = 0, 0
episodes = 100

for _ in range(episodes):
    state = env.reset()
    epochs, penalties, reward = 0, 0, 0
    
    done = False
    
    while not done:
        action = np.argmax(q_table[state])
        state, reward, done, info = env.step(action)

        if reward == -10:
            penalties += 1

        epochs += 1

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / episodes}")
print(f"Average penalties per episode: {total_penalties / episodes}")
# Out:
# Results after 100 episodes:
# Average timesteps per episode: 13.08
# Average penalties per episode: 0.0
