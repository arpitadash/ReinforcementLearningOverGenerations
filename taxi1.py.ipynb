# %%
import gym

env = gym.make("Taxi-v3").env

env.render()
env.reset() # reset environment to a new, random state
env.render()

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# Action Space Discrete(6)
# State Space Discrete(500)

# %%
state = env.encode(3, 1, 2, 0) # (taxi row, taxi column, passenger index, destination index)
print("State:", state)

env.s = state
env.render()
# Out:
# State: 328
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
import numpy as np
q_table = np.zeros([env.observation_space.n, env.action_space.n])

"""Training the agent"""
print("How many generations ?")
gen = int(input())

import random
from IPython.display import clear_output

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1
for j in range(gen):
    print("Gen : ", j+1)
    time_taken = 0
    # For plotting metrics
    all_epochs = []
    all_penalties = []
    frames = []
    for i in range(1, 100):
        state = env.reset()

        epochs, penalties, reward, = 0, 0, 0
        done = False

        while not done:
            if random.uniform(0, 1) < epsilon:
                action = env.action_space.sample() # Explore action space
            else:
                action = np.argmax(q_table[state]) # Exploit learned values

            next_state, reward, done, info = env.step(action) 

            old_value = q_table[state, action]
            next_max = np.max(q_table[next_state])

            new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
            q_table[state, action] = new_value

            if reward == -10:
                penalties += 1

            frames.append({
            'frame': env.render(mode='ansi'),
            'state': state,
            'action': action,
            'reward': reward
            }
        )

            state = next_state

            epochs += 1

        if i % 100 == 0:
            clear_output(wait=True)
            print(f"Episode: {i}")
        time_taken += epochs
    print(f"Total time in this generation is : {time_taken}")
    print("Training finished.\n")

from IPython.display import clear_output
from time import sleep

# def print_frames(frames):
#     for i, frame in enumerate(frames):
#         clear_output(wait=True)
#         print(frame['frame'].getvalue())
#         print(f"Timestep: {i + 1}")
#         print(f"State: {frame['state']}")
#         print(f"Action: {frame['action']}")
#         print(f"Reward: {frame['reward']}")
#         sleep(.1)
        
# print_frames(frames)
# Out:
# How many generations ?
# 200
# Gen :  1
# Total time in this generation is : 46016
# Training finished.
#
# Gen :  2
# Total time in this generation is : 20209
# Training finished.
#
# Gen :  3
# Total time in this generation is : 12449
# Training finished.
#
# Gen :  4
# Total time in this generation is : 9301
# Training finished.
#
# Gen :  5
# Total time in this generation is : 7200
# Training finished.
#
# Gen :  6
# Total time in this generation is : 6447
# Training finished.
#
# Gen :  7
# Total time in this generation is : 5750
# Training finished.
#
# Gen :  8
# Total time in this generation is : 4438
# Training finished.
#
# Gen :  9
# Total time in this generation is : 3882
# Training finished.
#
# Gen :  10
# Total time in this generation is : 3732
# Training finished.
#
# Gen :  11
# Total time in this generation is : 3357
# Training finished.
#
# Gen :  12
# Total time in this generation is : 2551
# Training finished.
#
# Gen :  13
# Total time in this generation is : 2641
# Training finished.
#
# Gen :  14
# Total time in this generation is : 2296
# Training finished.
#
# Gen :  15
# Total time in this generation is : 2638
# Training finished.
#
# Gen :  16
# Total time in this generation is : 2511
# Training finished.
#
# Gen :  17
# Total time in this generation is : 2038
# Training finished.
#
# Gen :  18
# Total time in this generation is : 2095
# Training finished.
#
# Gen :  19
# Total time in this generation is : 2224
# Training finished.
#
# Gen :  20
# Total time in this generation is : 1981
# Training finished.
#
# Gen :  21
# Total time in this generation is : 1953
# Training finished.
#
# Gen :  22
# Total time in this generation is : 1943
# Training finished.
#
# Gen :  23
# Total time in this generation is : 1916
# Training finished.
#
# Gen :  24
# Total time in this generation is : 1868
# Training finished.
#
# Gen :  25
# Total time in this generation is : 1883
# Training finished.
#
# Gen :  26
# Total time in this generation is : 1901
# Training finished.
#
# Gen :  27
# Total time in this generation is : 1858
# Training finished.
#
# Gen :  28
# Total time in this generation is : 1708
# Training finished.
#
# Gen :  29
# Total time in this generation is : 1697
# Training finished.
#
# Gen :  30
# Total time in this generation is : 1739
# Training finished.
#
# Gen :  31
# Total time in this generation is : 1737
# Training finished.
#
# Gen :  32
# Total time in this generation is : 1677
# Training finished.
#
# Gen :  33
# Total time in this generation is : 1621
# Training finished.
#
# Gen :  34
# Total time in this generation is : 1647
# Training finished.
#
# Gen :  35
# Total time in this generation is : 1583
# Training finished.
#
# Gen :  36
# Total time in this generation is : 1603
# Training finished.
#
# Gen :  37
# Total time in this generation is : 1647
# Training finished.
#
# Gen :  38
# Total time in this generation is : 1530
# Training finished.
#
# Gen :  39
# Total time in this generation is : 1606
# Training finished.
#
# Gen :  40
# Total time in this generation is : 1574
# Training finished.
#
# Gen :  41
# Total time in this generation is : 1615
# Training finished.
#
# Gen :  42
# Total time in this generation is : 1505
# Training finished.
#
# Gen :  43
# Total time in this generation is : 1582
# Training finished.
#
# Gen :  44
# Total time in this generation is : 1560
# Training finished.
#
# Gen :  45
# Total time in this generation is : 1561
# Training finished.
#
# Gen :  46
# Total time in this generation is : 1499
# Training finished.
#
# Gen :  47
# Total time in this generation is : 1620
# Training finished.
#
# Gen :  48
# Total time in this generation is : 1546
# Training finished.
#
# Gen :  49
# Total time in this generation is : 1583
# Training finished.
#
# Gen :  50
# Total time in this generation is : 1542
# Training finished.
#
# Gen :  51
# Total time in this generation is : 1560
# Training finished.
#
# Gen :  52
# Total time in this generation is : 1523
# Training finished.
#
# Gen :  53
# Total time in this generation is : 1566
# Training finished.
#
# Gen :  54
# Total time in this generation is : 1568
# Training finished.
#
# Gen :  55
# Total time in this generation is : 1598
# Training finished.
#
# Gen :  56
# Total time in this generation is : 1517
# Training finished.
#
# Gen :  57
# Total time in this generation is : 1480
# Training finished.
#
# Gen :  58
# Total time in this generation is : 1508
# Training finished.
#
# Gen :  59
# Total time in this generation is : 1541
# Training finished.
#
# Gen :  60
# Total time in this generation is : 1480
# Training finished.
#
# Gen :  61
# Total time in this generation is : 1399
# Training finished.
#
# Gen :  62
# Total time in this generation is : 1536
# Training finished.
#
# Gen :  63
# Total time in this generation is : 1498
# Training finished.
#
# Gen :  64
# Total time in this generation is : 1498
# Training finished.
#
# Gen :  65
# Total time in this generation is : 1404
# Training finished.
#
# Gen :  66
# Total time in this generation is : 1574
# Training finished.
#
# Gen :  67
# Total time in this generation is : 1472
# Training finished.
#
# Gen :  68
# Total time in this generation is : 1518
# Training finished.
#
# Gen :  69
# Total time in this generation is : 1497
# Training finished.
#
# Gen :  70
# Total time in this generation is : 1507
# Training finished.
#
# Gen :  71
# Total time in this generation is : 1512
# Training finished.
#
# Gen :  72
# Total time in this generation is : 1452
# Training finished.
#
# Gen :  73
# Total time in this generation is : 1512
# Training finished.
#
# Gen :  74
# Total time in this generation is : 1442
# Training finished.
#
# Gen :  75
# Total time in this generation is : 1483
# Training finished.
#
# Gen :  76
# Total time in this generation is : 1521
# Training finished.
#
# Gen :  77
# Total time in this generation is : 1418
# Training finished.
#
# Gen :  78
# Total time in this generation is : 1506
# Training finished.
#
# Gen :  79
# Total time in this generation is : 1481
# Training finished.
#
# Gen :  80
# Total time in this generation is : 1516
# Training finished.
#
# Gen :  81
# Total time in this generation is : 1429
# Training finished.
#
# Gen :  82
# Total time in this generation is : 1534
# Training finished.
#
# Gen :  83
# Total time in this generation is : 1453
# Training finished.
#
# Gen :  84
# Total time in this generation is : 1483
# Training finished.
#
# Gen :  85
# Total time in this generation is : 1560
# Training finished.
#
# Gen :  86
# Total time in this generation is : 1453
# Training finished.
#
# Gen :  87
# Total time in this generation is : 1486
# Training finished.
#
# Gen :  88
# Total time in this generation is : 1447
# Training finished.
#
# Gen :  89
# Total time in this generation is : 1500
# Training finished.
#
# Gen :  90
# Total time in this generation is : 1482
# Training finished.
#
# Gen :  91
# Total time in this generation is : 1472
# Training finished.
#
# Gen :  92
# Total time in this generation is : 1475
# Training finished.
#
# Gen :  93
# Total time in this generation is : 1445
# Training finished.
#
# Gen :  94
# Total time in this generation is : 1544
# Training finished.
#
# Gen :  95
# Total time in this generation is : 1503
# Training finished.
#
# Gen :  96
# Total time in this generation is : 1542
# Training finished.
#
# Gen :  97
# Total time in this generation is : 1502
# Training finished.
#
# Gen :  98
# Total time in this generation is : 1482
# Training finished.
#
# Gen :  99
# Total time in this generation is : 1481
# Training finished.
#
# Gen :  100
# Total time in this generation is : 1517
# Training finished.
#
# Gen :  101
# Total time in this generation is : 1525
# Training finished.
#
# Gen :  102
# Total time in this generation is : 1447
# Training finished.
#
# Gen :  103
# Total time in this generation is : 1466
# Training finished.
#
# Gen :  104
# Total time in this generation is : 1485
# Training finished.
#
# Gen :  105
# Total time in this generation is : 1512
# Training finished.
#
# Gen :  106
# Total time in this generation is : 1494
# Training finished.
#
# Gen :  107
# Total time in this generation is : 1451
# Training finished.
#
# Gen :  108
# Total time in this generation is : 1488
# Training finished.
#
# Gen :  109
# Total time in this generation is : 1474
# Training finished.
#
# Gen :  110
# Total time in this generation is : 1485
# Training finished.
#
# Gen :  111
# Total time in this generation is : 1507
# Training finished.
#
# Gen :  112
# Total time in this generation is : 1453
# Training finished.
#
# Gen :  113
# Total time in this generation is : 1511
# Training finished.
#
# Gen :  114
# Total time in this generation is : 1512
# Training finished.
#
# Gen :  115
# Total time in this generation is : 1413
# Training finished.
#
# Gen :  116
# Total time in this generation is : 1428
# Training finished.
#
# Gen :  117
# Total time in this generation is : 1431
# Training finished.
#
# Gen :  118
# Total time in this generation is : 1417
# Training finished.
#
# Gen :  119
# Total time in this generation is : 1499
# Training finished.
#
# Gen :  120
# Total time in this generation is : 1511
# Training finished.
#
# Gen :  121
# Total time in this generation is : 1465
# Training finished.
#
# Gen :  122
# Total time in this generation is : 1449
# Training finished.
#
# Gen :  123
# Total time in this generation is : 1508
# Training finished.
#
# Gen :  124
# Total time in this generation is : 1477
# Training finished.
#
# Gen :  125
# Total time in this generation is : 1457
# Training finished.
#
# Gen :  126
# Total time in this generation is : 1464
# Training finished.
#
# Gen :  127
# Total time in this generation is : 1481
# Training finished.
#
# Gen :  128
# Total time in this generation is : 1485
# Training finished.
#
# Gen :  129
# Total time in this generation is : 1517
# Training finished.
#
# Gen :  130
# Total time in this generation is : 1450
# Training finished.
#
# Gen :  131
# Total time in this generation is : 1430
# Training finished.
#
# Gen :  132
# Total time in this generation is : 1496
# Training finished.
#
# Gen :  133
# Total time in this generation is : 1501
# Training finished.
#
# Gen :  134
# Total time in this generation is : 1468
# Training finished.
#
# Gen :  135
# Total time in this generation is : 1399
# Training finished.
#
# Gen :  136
# Total time in this generation is : 1482
# Training finished.
#
# Gen :  137
# Total time in this generation is : 1476
# Training finished.
#
# Gen :  138
# Total time in this generation is : 1423
# Training finished.
#
# Gen :  139
# Total time in this generation is : 1437
# Training finished.
#
# Gen :  140
# Total time in this generation is : 1436
# Training finished.
#
# Gen :  141
# Total time in this generation is : 1410
# Training finished.
#
# Gen :  142
# Total time in this generation is : 1464
# Training finished.
#
# Gen :  143
# Total time in this generation is : 1469
# Training finished.
#
# Gen :  144
# Total time in this generation is : 1431
# Training finished.
#
# Gen :  145
# Total time in this generation is : 1464
# Training finished.
#
# Gen :  146
# Total time in this generation is : 1425
# Training finished.
#
# Gen :  147
# Total time in this generation is : 1473
# Training finished.
#
# Gen :  148
# Total time in this generation is : 1447
# Training finished.
#
# Gen :  149
# Total time in this generation is : 1470
# Training finished.
#
# Gen :  150
# Total time in this generation is : 1464
# Training finished.
#
# Gen :  151
# Total time in this generation is : 1508
# Training finished.
#
# Gen :  152
# Total time in this generation is : 1448
# Training finished.
#
# Gen :  153
# Total time in this generation is : 1423
# Training finished.
#
# Gen :  154
# Total time in this generation is : 1452
# Training finished.
#
# Gen :  155
# Total time in this generation is : 1471
# Training finished.
#
# Gen :  156
# Total time in this generation is : 1485
# Training finished.
#
# Gen :  157
# Total time in this generation is : 1379
# Training finished.
#
# Gen :  158
# Total time in this generation is : 1498
# Training finished.
#
# Gen :  159
# Total time in this generation is : 1489
# Training finished.
#
# Gen :  160
# Total time in this generation is : 1466
# Training finished.
#
# Gen :  161
# Total time in this generation is : 1441
# Training finished.
#
# Gen :  162
# Total time in this generation is : 1430
# Training finished.
#
# Gen :  163
# Total time in this generation is : 1409
# Training finished.
#
# Gen :  164
# Total time in this generation is : 1433
# Training finished.
#
# Gen :  165
# Total time in this generation is : 1469
# Training finished.
#
# Gen :  166
# Total time in this generation is : 1473
# Training finished.
#
# Gen :  167
# Total time in this generation is : 1476
# Training finished.
#
# Gen :  168
# Total time in this generation is : 1436
# Training finished.
#
# Gen :  169
# Total time in this generation is : 1492
# Training finished.
#
# Gen :  170
# Total time in this generation is : 1493
# Training finished.
#
# Gen :  171
# Total time in this generation is : 1405
# Training finished.
#
# Gen :  172
# Total time in this generation is : 1448
# Training finished.
#
# Gen :  173
# Total time in this generation is : 1489
# Training finished.
#
# Gen :  174
# Total time in this generation is : 1439
# Training finished.
#
# Gen :  175
# Total time in this generation is : 1428
# Training finished.
#
# Gen :  176
# Total time in this generation is : 1469
# Training finished.
#
# Gen :  177
# Total time in this generation is : 1430
# Training finished.
#
# Gen :  178
# Total time in this generation is : 1456
# Training finished.
#
# Gen :  179
# Total time in this generation is : 1422
# Training finished.
#
# Gen :  180
# Total time in this generation is : 1457
# Training finished.
#
# Gen :  181
# Total time in this generation is : 1501
# Training finished.
#
# Gen :  182
# Total time in this generation is : 1500
# Training finished.
#
# Gen :  183
# Total time in this generation is : 1475
# Training finished.
#
# Gen :  184
# Total time in this generation is : 1448
# Training finished.
#
# Gen :  185
# Total time in this generation is : 1393
# Training finished.
#
# Gen :  186
# Total time in this generation is : 1463
# Training finished.
#
# Gen :  187
# Total time in this generation is : 1491
# Training finished.
#
# Gen :  188
# Total time in this generation is : 1459
# Training finished.
#
# Gen :  189
# Total time in this generation is : 1433
# Training finished.
#
# Gen :  190
# Total time in this generation is : 1440
# Training finished.
#
# Gen :  191
# Total time in this generation is : 1498
# Training finished.
#
# Gen :  192
# Total time in this generation is : 1492
# Training finished.
#
# Gen :  193
# Total time in this generation is : 1481
# Training finished.
#
# Gen :  194
# Total time in this generation is : 1379
# Training finished.
#
# Gen :  195
# Total time in this generation is : 1453
# Training finished.
#
# Gen :  196
# Total time in this generation is : 1475
# Training finished.
#
# Gen :  197
# Total time in this generation is : 1420
# Training finished.
#
# Gen :  198
# Total time in this generation is : 1485
# Training finished.
#
# Gen :  199
# Total time in this generation is : 1489
# Training finished.
#
# Gen :  200
# Total time in this generation is : 1379
# Training finished.

# %%
"""Evaluate agent's performance after Q-learning"""

total_epochs, total_penalties = 0, 0
episodes = 100

for _ in range(episodes):
    state = env.reset()
    epochs, penalties, reward = 0, 0, 0
    
    done = False
    
    while not done:
        action = np.argmax(q_table[state])
        state, reward, done, info = env.step(action)

        if reward == -10:
            penalties += 1

        epochs += 1

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / episodes}")
print(f"Average penalties per episode: {total_penalties / episodes}")
# Out:
# Results after 100 episodes:
# Average timesteps per episode: 13.21
# Average penalties per episode: 0.0
